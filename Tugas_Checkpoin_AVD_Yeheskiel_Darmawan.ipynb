# %% [markdown]
# # **Checkpoin 1**

# %% [markdown]
# # **Analisis Faktor yang Mempengaruhi Kinerja dan Retensi Karyawan**

# %%
import pandas as pd

# %%
file = "/content/drive/MyDrive/Messy_Employee_dataset.csv"
df = pd.read_csv(file)

df
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2        EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# 0       4/2/2021   59767.65         bob.davis@example.com -1651623197
# 1      7/10/2020   65304.66         bob.brown@example.com -1898471390
# 2      12/7/2023   88145.90       alice.jones@example.com -5596363211
# 3     11/27/2021   69450.99         eva.davis@example.com -3476490784
# 4       1/5/2022  109324.61    frank.williams@example.com -1586734256
# ...          ...        ...                           ...         ...
# 1015   8/19/2023        NaN      david.miller@example.com -3546212759
# 1016   11/7/2021  100215.06     david.johnson@example.com -2508261122
# 1017   10/4/2023  114587.11  charlie.williams@example.com -1261632487
# 1018  12/16/2024   71318.79      alice.garcia@example.com -8995729892
# 1019   2/22/2021   77764.24       heidi.jones@example.com -7629745492
#
#      Performance_Score  Remote_Work
# 0              Average         True
# 1            Excellent         True
# 2                 Good         True
# 3                 Good         True
# 4                 Poor        False
# ...                ...          ...
# 1015              Good         True
# 1016              Good         True
# 1017           Average        False
# 1018              Good         True
# 1019           Average        False
#
# [1020 rows x 12 columns]

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# Analisis ini dilakukan untuk memahami kondisi karyawan di perusahaan berdasarkan data yang tersedia. Dari dataset tersebut, terlihat bahwa terdapat informasi seperti usia, salary, pengalaman kerja, departemen, dan performance rating yang dapat digunakan untuk melihat pola tertentu. Selain itu, terdapat beberapa data yang masih kosong sehingga perlu diperhatikan sebelum analisis lebih lanjut dilakukan. Melalui analisis ini, diharapkan perusahaan bisa mendapatkan gambaran yang lebih jelas mengenai faktor yang mempengaruhi performa dan keberlangsungan kerja karyawan

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# Mengetahui faktor yang paling berpengaruh terhadap kinerja dan keputusan karyawan untuk tetap bekerja atau resign, sehingga perusahaan dapat mengambil keputusan yang lebih tepat dalam mengelola SDM

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# *   **Ketersediaan Data**
# Dataset sudah tersedia dan berisi informasi mengenai usia, salary, pengalaman kerja, departemen, performance rating, dan status kerja karyawan
#
# *   **Kondisi Data**
# Dari pengecekan awal, ditemukan beberapa nilai yang kosong pada kolom tertentu seperti Age dan Salary, sehingga perlu dilakukan pembersihan data sebelum analisis lebih lanjut
#
# *   **Kesiapan Analisis**
# Secara umum data sudah cukup untuk dilakukan eksplorasi, namun tetap diperlukan tahap persiapan agar hasil analisis lebih akurat dan tidak bias

# %% [markdown]
# ## **Analytic Goals**

# %% [markdown]
# **Tujuan analisis dalam proyek ini adalah:**
#
# * **Mengidentifikasi faktor yang mempengaruhi performance karyawan**
# Melihat apakah variabel seperti salary, usia, dan pengalaman kerja memiliki hubungan dengan performance rating
#
# * **Menganalisis pola karyawan yang resign**
# Mengamati apakah terdapat karakteristik tertentu pada karyawan yang keluar dibandingkan dengan yang masih aktif
#
# * **Mengevaluasi kesesuaian antara salary dan pengalaman kerja**
# Menilai apakah terdapat pola yang menunjukkan hubungan yang wajar antara pengalaman kerja dan tingkat gaji
#
# * **Memberikan gambaran awal berbasis data**
# Menyusun hasil analisis sebagai dasar untuk pemahaman kondisi karyawan secara keseluruhan

# %% [markdown]
# ## **Project Plan**

# %% [markdown]
# **Tahapan yang akan dilakukan dalam proyek ini meliputi:**
#
# 1.   **Business Understanding**
# Memahami latar belakang permasalahan serta tujuan analisis yang ingin dicapai
# 2.   **Data Understanding**
# Melakukan pengecekan awal terhadap struktur dataset, tipe variabel, serta keberadaan nilai yang kosong
# 1.   **Data Preparation**
# Membersihkan dan menyiapkan data agar siap untuk proses analisis selanjutnya
# 2.   **Exploratory Data Analysis (EDA)**
# Melakukan analisis awal untuk melihat pola atau hubungan antar variabel yang berpotensi berpengaruh terhadap kinerja dan status kerja karyawan

# %% [markdown]
# # **Checkpoint 2**

# %% [markdown]
# # **Data Understanding & Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Memuat Dataset**

# %%
file = '/content/drive/MyDrive/Messy_Employee_dataset.csv'

df = pd.read_csv(file)
df
# Out:
#      Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0        EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1        EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2        EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3        EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4        EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
# ...          ...        ...       ...   ...                 ...       ...
# 1015     EMP2015      David    Miller  30.0       HR-California    Active
# 1016     EMP2016      David   Johnson  30.0    Cloud Tech-Texas  Inactive
# 1017     EMP2017    Charlie  Williams  40.0    Finance-New York    Active
# 1018     EMP2018      Alice    Garcia  30.0          HR-Florida  Inactive
# 1019     EMP2019      Heidi     Jones  30.0     DevOps-Illinois   Pending
#
#        Join_Date     Salary                         Email       Phone  \
# 0       4/2/2021   59767.65         bob.davis@example.com -1651623197
# 1      7/10/2020   65304.66         bob.brown@example.com -1898471390
# 2      12/7/2023   88145.90       alice.jones@example.com -5596363211
# 3     11/27/2021   69450.99         eva.davis@example.com -3476490784
# 4       1/5/2022  109324.61    frank.williams@example.com -1586734256
# ...          ...        ...                           ...         ...
# 1015   8/19/2023        NaN      david.miller@example.com -3546212759
# 1016   11/7/2021  100215.06     david.johnson@example.com -2508261122
# 1017   10/4/2023  114587.11  charlie.williams@example.com -1261632487
# 1018  12/16/2024   71318.79      alice.garcia@example.com -8995729892
# 1019   2/22/2021   77764.24       heidi.jones@example.com -7629745492
#
#      Performance_Score  Remote_Work
# 0              Average         True
# 1            Excellent         True
# 2                 Good         True
# 3                 Good         True
# 4                 Poor        False
# ...                ...          ...
# 1015              Good         True
# 1016              Good         True
# 1017           Average        False
# 1018              Good         True
# 1019           Average        False
#
# [1020 rows x 12 columns]

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# ## Struktur Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        1020 non-null   object
#  1   First_Name         1020 non-null   object
#  2   Last_Name          1020 non-null   object
#  3   Age                809 non-null    float64
#  4   Department_Region  1020 non-null   object
#  5   Status             1020 non-null   object
#  6   Join_Date          1020 non-null   object
#  7   Salary             996 non-null    float64
#  8   Email              1020 non-null   object
#  9   Phone              1020 non-null   int64
#  10  Performance_Score  1020 non-null   object
#  11  Remote_Work        1020 non-null   bool
# dtypes: bool(1), float64(2), int64(1), object(8)
# memory usage: 88.8+ KB

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'First_Name', 'Last_Name', 'Age', 'Department_Region',
#        'Status', 'Join_Date', 'Salary', 'Email', 'Phone', 'Performance_Score',
#        'Remote_Work'],
#       dtype='object')

# %% [markdown]
# **Insight**:
# - Dataset memiliki sejumlah baris dan kolom
# - Beberapa kolom seperti Salary dan Join_Date masih bertipe object
# - Perlu penyesuaian tipe data sebelum analisis lebih lanjut

# %% [markdown]
# ## **Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        Employee_ID First_Name Last_Name         Age Department_Region  \
# count         1020       1020      1020  809.000000              1020
# unique        1020          8         8         NaN                36
# top        EMP2019      Frank     Brown         NaN        HR-Florida
# freq             1        142       148         NaN                41
# mean           NaN        NaN       NaN   32.484549               NaN
# std            NaN        NaN       NaN    5.656860               NaN
# min            NaN        NaN       NaN   25.000000               NaN
# 25%            NaN        NaN       NaN   25.000000               NaN
# 50%            NaN        NaN       NaN   30.000000               NaN
# 75%            NaN        NaN       NaN   40.000000               NaN
# max            NaN        NaN       NaN   40.000000               NaN
#
#          Status  Join_Date         Salary                    Email  \
# count      1020       1020     996.000000                     1020
# unique        3        760            NaN                       64
# top     Pending  6/10/2024            NaN  grace.brown@example.com
# freq        356          5            NaN                       27
# mean        NaN        NaN   85155.056396                      NaN
# std         NaN        NaN   19873.727918                      NaN
# min         NaN        NaN   50047.320000                      NaN
# 25%         NaN        NaN   68392.487500                      NaN
# 50%         NaN        NaN   85547.870000                      NaN
# 75%         NaN        NaN  100974.027500                      NaN
# max         NaN        NaN  119971.650000                      NaN
#
#                Phone Performance_Score Remote_Work
# count   1.020000e+03              1020        1020
# unique           NaN                 4           2
# top              NaN              Good        True
# freq             NaN               270         513
# mean   -4.942253e+09               NaN         NaN
# std     2.817326e+09               NaN         NaN
# min    -9.994973e+09               NaN         NaN
# 25%    -7.341992e+09               NaN         NaN
# 50%    -4.943997e+09               NaN         NaN
# 75%    -2.520391e+09               NaN         NaN
# max    -3.896086e+06               NaN         NaN

# %% [markdown]
# **Insight:**
# - Terdapat variasi nilai pada kolom numerik
# - Kategori pada kolom teks menunjukkan kemungkinan inkonsistensi

# %% [markdown]
# ## **Cek Tipe Data**

# %%
df.dtypes
# Out:
# Employee_ID           object
# First_Name            object
# Last_Name             object
# Age                  float64
# Department_Region     object
# Status                object
# Join_Date             object
# Salary               float64
# Email                 object
# Phone                  int64
# Performance_Score     object
# Remote_Work             bool
# dtype: object

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil pengecekan tipe data, kolom numerik seperti Age, Work_Experience, dan Salary_num sudah bertipe int/float sehingga siap digunakan untuk analisis statistik.
# Kolom Employee_ID, Dept, dan Status bertipe object karena merupakan data kategorikal.
# Secara umum, tipe data sudah sesuai dan tidak memerlukan perubahan lebih lanjut.

# %% [markdown]
# ## **Cek Inconsistent Values**

# %% [markdown]
# ## **Cek Seluruh Kolom Category**

# %%
cols = df.select_dtypes(include='object')

for col in cols:
    print("Kolom :", col)
    print(df[col].unique())
# Out:
# Kolom : Employee_ID
# ['EMP1000' 'EMP1001' 'EMP1002' ... 'EMP2017' 'EMP2018' 'EMP2019']
# Kolom : First_Name
# ['Bob' 'Alice' 'Eva' 'Frank' 'Charlie' 'David' 'Heidi' 'Grace']
# Kolom : Last_Name
# ['Davis' 'Brown' 'Jones' 'Williams' 'Garcia' 'Johnson' 'Miller' 'Smith']
# Kolom : Department_Region
# ['DevOps-California' 'Finance-Texas' 'Admin-Nevada' 'Cloud Tech-Florida'
#  'Sales-Texas' 'DevOps-New York' 'Cloud Tech-New York' 'HR-New York'
#  'Finance-California' 'Sales-Florida' 'DevOps-Illinois'
#  'Cloud Tech-Nevada' 'Admin-Illinois' 'Cloud Tech-Illinois'
#  'Sales-Illinois' 'Finance-Nevada' 'Admin-Texas' 'Sales-New York'
#  '10/28/2021' '5/5/2020' '12/24/2022' '9/5/2021' '1/29/2023' '6/3/2022'
#  '1/21/2023' '2/2/2020' '7/8/2024' '5/18/2022' '1/16/2020' '3/26/2023'
#  '3/21/2023' '5/8/2023' '12/12/2020' '6/17/2020' '7/17/2021' '11/5/2020'
#  '1/5/2021' '9/11/2024' '4/17/2020' '2/16/2022' '8/14/2021' '7/7/2021'
#  '2/12/2024' '7/7/2020' '9/2/2020' '1/12/2021' '2/14/2021' '5/24/2020'
#  '3/12/2022' '5/18/2024' '9/18/2024' '6/15/2022' '9/28/2022' '9/28/2023'
#  '3/25/2023' '7/1/2020' '9/16/2020' '12/13/2021' '1/11/2022' '7/20/2021'
#  '10/4/2023' '11/15/2021' '1/17/2024' '4/16/2021' '6/2/2023' '1/30/2020'
#  '3/31/2021' '7/16/2024' '6/1/2024' '12/23/2024' '10/28/2022' '11/20/2023'
#  '3/11/2022' '5/3/2022' '2/19/2024' '11/18/2021' '12/21/2022' '7/22/2022'
#  '10/10/2021' '3/12/2020' '9/7/2022' '10/5/2024' '10/12/2021' '10/14/2024'
#  '7/1/2022' '10/21/2020' '1/14/2020' '3/9/2023' '4/4/2021' '9/11/2020'
#  '5/16/2021' '11/15/2022' '10/22/2021' '8/3/2024' '5/15/2020' '2/13/2021'
#  '8/5/2024' '1/9/2020' '11/30/2023' '10/5/2020' '10/22/2023' '9/10/2023'
#  '4/15/2024' '8/27/2024' '11/8/2020' '8/24/2021' '2/6/2020' '10/12/2024'
#  '4/13/2024' '10/18/2021' '2/25/2020' '6/22/2020' '1/7/2023' '11/26/2021'
#  '9/17/2024' '7/13/2021' '12/11/2023' '7/2/2021' '12/5/2022' '9/24/2024'
#  '8/16/2023' '1/28/2021']
# Kolom : Email
# ['bob.davis@example.com' 'bob.brown@example.com' 'alice.jones@example.com'
#  'eva.davis@example.com' 'frank.williams@example.com'
#  'alice.garcia@example.com' 'frank.jones@example.com'
#  'bob.jones@example.com' 'frank.davis@example.com'
#  'charlie.johnson@example.com' 'david.williams@example.com'
#  'david.davis@example.com' 'heidi.williams@example.com'
#  'grace.williams@example.com' 'grace.jones@example.com'
#  'alice.brown@example.com' 'grace.garcia@example.com'
#  'charlie.garcia@example.com' 'charlie.williams@example.com'
#  'bob.miller@example.com' 'david.garcia@example.com'
#  'david.miller@example.com' 'frank.miller@example.com'
#  'heidi.johnson@example.com' 'charlie.jones@example.com'
#  'bob.smith@example.com' 'charlie.brown@example.com'
#  'grace.johnson@example.com' 'heidi.miller@example.com'
#  'grace.smith@example.com' 'frank.smith@example.com'
#  'eva.williams@example.com' 'bob.williams@example.com'
#  'alice.johnson@example.com' 'bob.garcia@example.com'
#  'eva.brown@example.com' 'alice.davis@example.com'
#  'alice.miller@example.com' 'grace.miller@example.com'
#  'charlie.davis@example.com' 'frank.garcia@example.com'
#  'alice.smith@example.com' 'charlie.smith@example.com'
#  'bob.johnson@example.com' 'grace.brown@example.com'
#  'david.johnson@example.com' 'david.brown@example.com'
#  'grace.davis@example.com' 'frank.brown@example.com'
#  'david.jones@example.com' 'heidi.garcia@example.com'
#  'eva.miller@example.com' 'frank.johnson@example.com'
#  'eva.jones@example.com' 'eva.garcia@example.com'
#  'heidi.jones@example.com' 'eva.johnson@example.com'
#  'david.smith@example.com' 'alice.williams@example.com'
#  'heidi.smith@example.com' 'heidi.davis@example.com'
#  'heidi.brown@example.com' 'charlie.miller@example.com'
#  'eva.smith@example.com']
# Kolom : Performance_Score
# ['Average' 'Excellent' 'Good' 'Poor']

# %% [markdown]
# **Insight:**
#
# - Technology
# - technology
# - TECHNOLOGY

# %% [markdown]
# ## **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                    Null Ratio in %
# Employee_ID               0.000000
# First_Name                0.000000
# Last_Name                 0.000000
# Age                      20.686275
# Department_Region         0.000000
# Status                    0.000000
# Join_Date                 0.000000
# Salary                    2.352941
# Email                     0.000000
# Phone                     0.000000
# Performance_Score         0.000000
# Remote_Work               0.000000

# %% [markdown]
# **Insight:**
# - Beberapa kolom memiliki missing values yang signifikan.
# - Perlu dilakukan imputasi atau pembersihan.

# %% [markdown]
# ## **Duplicate Values**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Insight:**
# - Data duplikat dapat mempengaruhi hasil agregasi dan analisis

# %% [markdown]
# ## **Outliers (Salary)**

# %%
df['Salary_num'] = pd.to_numeric(df['Salary'].replace('[\$,]', '', regex=True), errors='coerce')
sns.boxplot(x=df['Salary_num'])
plt.title('Outliers in Salary')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-2161983471.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['Salary_num'] = pd.to_numeric(df['Salary'].replace('[\$,]', '', regex=True), errors='coerce')

# %% [markdown]
# **Insight:**
# - Terdapat nilai salary ekstrem yang perlu dianalisis lebih lanjut

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## **Comparison – Average Salary per Department**

# %%
df.groupby('Department_Region')['Salary_num'].mean().sort_values().plot(kind='bar')
plt.title('Average Salary per Department_Region')
plt.ylabel('Average Salary')
plt.show()

# %% [markdown]
# **Insight:**
# - Terdapat perbedaan rata-rata salary antar departemen

# %% [markdown]
# ## **Composition – Employee Status**

# %%
df['Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Komposisi Status Karyawan')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insight:**
# - Mayoritas karyawan berada pada satu kategori status tertentu

# %% [markdown]
# ## **Distribution – Age**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Salary'], kde=True)
plt.title('Distribusi Salary')
plt.xlabel('Salary')
plt.show()

# %% [markdown]
# **Insight:**
# - Distribusi usia menunjukkan pola tertentu dalam populasi karyawan

# %% [markdown]
# ## **Relationship – Salary vs Performance Score**

# %%
sns.boxplot(x='Performance_Score', y='Salary_num', data=df)
plt.title('Salary vs Performance Score')
plt.show()

# %% [markdown]
# **Insight:**
# - Karyawan dengan performa lebih tinggi cenderung memiliki salary lebih tinggi
